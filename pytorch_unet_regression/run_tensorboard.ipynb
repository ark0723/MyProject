# %%
# %load_ext tensorboard

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorboard --logdir "/content/drive/MyDrive/pytorch_unet_regression/log/inpainting/plain"

# %%
# %tensorboard --logdir "/content/drive/MyDrive/pytorch_unet_regression/log/inpainting/residual"

# %%
# %tensorboard --logdir "/content/drive/MyDrive/pytorch_unet_regression/log/denoising/plain"

# %%
# %tensorboard --logdir "/content/drive/MyDrive/pytorch_unet_regression/log/denoising/residual"

# %%
# %tensorboard --logdir "/content/drive/MyDrive/pytorch_unet_regression/log/super_resolution/plain"

# %%
# %tensorboard --logdir "/content/drive/MyDrive/pytorch_unet_regression/log/super_resolution/residual"
